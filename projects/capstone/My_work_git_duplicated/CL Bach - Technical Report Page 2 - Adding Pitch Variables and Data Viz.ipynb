# %% [markdown]
# # CL Bach: Using Machine Learning to Compose New Bach Chorales
# ----------------
# (Page 2)
# The dataframe still has embedded music21 objects. (That is why I pickled instead of exporting and importing as a CSV file).
#
# In order to use the data in models, the data must be in categorical or continuous variables. This page seeks to do that.

# %%
import music21 as m21

import pandas as pd
import numpy as np

import copy
import cPickle

# %%
f = open('bach.p', 'rb')
bach_df = cPickle.load(f)
f.close()

# %%
bach_df.head()
# Out:
#              BWV orig_key  beats_per_measure  forward_note  back_note  \
# bwv421_0  bwv421  a minor                  4             0        159
# bwv421_1  bwv421  a minor                  4             1        158
# bwv421_2  bwv421  a minor                  4             2        157
# bwv421_3  bwv421  a minor                  4             3        156
# bwv421_4  bwv421  a minor                  4             4        155
#
#           forward_measure  back_measure  note_in_measure_position  \
# bwv421_0                0            10                         1
# bwv421_1                0            10                         2
# bwv421_2                0            10                         3
# bwv421_3                0            10                         4
# bwv421_4                1             9                         1
#
#           quarter_in_measure_position                soprano  \
# bwv421_0                            4  <music21.note.Note G>
# bwv421_1                            4  <music21.note.Note G>
# bwv421_2                            4  <music21.note.Note G>
# bwv421_3                            4  <music21.note.Note G>
# bwv421_4                            1  <music21.note.Note G>
#
#                            alto                   tenor  \
# bwv421_0  <music21.note.Note D>  <music21.note.Note B->
# bwv421_1  <music21.note.Note D>  <music21.note.Note B->
# bwv421_2  <music21.note.Note D>   <music21.note.Note C>
# bwv421_3  <music21.note.Note D>   <music21.note.Note C>
# bwv421_4  <music21.note.Note D>   <music21.note.Note D>
#
#                             bass
# bwv421_0   <music21.note.Note G>
# bwv421_1   <music21.note.Note G>
# bwv421_2   <music21.note.Note A>
# bwv421_3   <music21.note.Note A>
# bwv421_4  <music21.note.Note B->

# %% [markdown]
# ## Create functions to create and substitute categorical and continuous pitch variables for each note in the dataframe.
#
# Each note's pitch is defined by the pitch letter (taken from the set [C, D, E, F, G, A, B] as well as the octave it's in: [0, 1, 2, 3, 4...] (see https://en.wikipedia.org/wiki/Scientific_pitch_notation).
#
# For categorical variables, I wanted to keep both pieces of information, so the variable is simply a string with the pitch letter and the octave - for example, 'C4' is middle C, 'G4' is the G above middle C. In music21, sharps are notated as "#" and flats are notated as '-'. For example, C# above middle C is 'C#4' and B-flat below middle C is 'B-3'.
#
# For continuous variables, I set G4, the tonic and most common note for the soprano line, as equal to 1. All other notes were identified as below or above G4, so accordingly, below or above 1.
#
# Rests were a little weird to handle.  For categorical variables, I replaced them with 'Rest'. For continuous variables, I would have loved to use np.nan, because that seems to coincide best with the actual meaning of a rest (the absence of a note), but most models do not play well with NaNs. So I'm not sure if this will work, but I decided to set Rests as a large number - so large it would be way off the hertz frequency charts and way beyond audible for human ears! We'll see later how the model likes or doesn't like that.

# %%
# a function that determines what 'pitch number' each pitch is.  
# this uses the basis that G4 = 1. I am using G4 because I want to
# make all bach chorales be in the key of G

def define_pitch_number(a_note):
    if type(a_note) == m21.note.Note:
    
        # identify how far the pitch is from G4
        interval_from_G4 = m21.interval.Interval(
                                noteStart= m21.note.Note('G4'), 
                                noteEnd  = a_note)

        # return this interval in terms of number of half steps
        pitch_offset = interval_from_G4.semitones

        # the new pitch number is relative to G4 = 100
        # so offset it by the pitch offset
        new_pitch_number = 1 + pitch_offset
        
    else:
        new_pitch_number = 1000000
    
    return new_pitch_number

# %%
# make a function to turn a note into a pitch category - ie. 'G4'
# input is a df
# no output; it changes the df
def create_cat_pitch_vars(df):
    
    for column in ['soprano', 'alto','tenor', 'bass']:
        a_list  = df[column].tolist()
        
        # create categorical pitch column
        cat_col_name = column + '_pitch_cat'
        
        # map using note pitch data
        df[cat_col_name] = [x.pitch.nameWithOctave if type(x) == m21.note.Note else 'Rest' for x in a_list]
        #.pitch.nameWithOctave)
#         print column, cat_col_name, df.loc[:,column][0]
         
    return df

# %%
# make a function to turn a note into a pitch category - ie. 'G4'
# input is a df
# no output; it changes the df
def create_cont_pitch_vars(df):
    for column in ['soprano', 'alto','tenor', 'bass']:
        a_list = df[column]
        
        # create continuous pitch column
        cont_col_name = column + '_pitch_cont'

        df[cont_col_name] = [define_pitch_number(x) for x in a_list]

    return df

# %%
bach_df = create_cat_pitch_vars(bach_df)

# %%
bach_df[bach_df['soprano_pitch_cat']=='Rest']
# looking good
# Out:
#                BWV  orig_key  beats_per_measure  forward_note  back_note  \
# bwv346_76   bwv346   C major                  4            76        167
# bwv346_77   bwv346   C major                  4            77        166
# bwv346_78   bwv346   C major                  4            78        165
# bwv346_79   bwv346   C major                  4            79        164
# bwv346_124  bwv346   C major                  4           124        119
# bwv346_125  bwv346   C major                  4           125        118
# bwv346_126  bwv346   C major                  4           126        117
# bwv346_127  bwv346   C major                  4           127        116
# bwv341_44   bwv341   g minor                  4            44         99
# bwv341_45   bwv341   g minor                  4            45         98
# bwv341_46   bwv341   g minor                  4            46         97
# bwv341_47   bwv341   g minor                  4            47         96
# bwv341_92   bwv341   g minor                  4            92         51
# bwv341_93   bwv341   g minor                  4            93         50
# bwv341_94   bwv341   g minor                  4            94         49
# bwv341_95   bwv341   g minor                  4            95         48
# bwv427_28   bwv427  E- major                  4            28        195
# bwv427_29   bwv427  E- major                  4            29        194
# bwv427_30   bwv427  E- major                  4            30        193
# bwv427_31   bwv427  E- major                  4            31        192
# bwv427_60   bwv427  E- major                  4            60        163
# bwv427_61   bwv427  E- major                  4            61        162
# bwv427_62   bwv427  E- major                  4            62        161
# bwv427_63   bwv427  E- major                  4            63        160
# bwv427_92   bwv427  E- major                  4            92        131
# bwv427_93   bwv427  E- major                  4            93        130
# bwv427_94   bwv427  E- major                  4            94        129
# bwv427_95   bwv427  E- major                  4            95        128
# bwv427_156  bwv427  E- major                  4           156         67
# bwv427_157  bwv427  E- major                  4           157         66
# ...            ...       ...                ...           ...        ...
# bwv433_306  bwv433   G major                  4           306        157
# bwv433_307  bwv433   G major                  4           307        156
# bwv433_344  bwv433   G major                  4           344        119
# bwv433_345  bwv433   G major                  4           345        118
# bwv433_346  bwv433   G major                  4           346        117
# bwv433_347  bwv433   G major                  4           347        116
# bwv433_368  bwv433   G major                  4           368         95
# bwv433_369  bwv433   G major                  4           369         94
# bwv433_370  bwv433   G major                  4           370         93
# bwv433_371  bwv433   G major                  4           371         92
# bwv433_392  bwv433   G major                  4           392         71
# bwv433_393  bwv433   G major                  4           393         70
# bwv433_394  bwv433   G major                  4           394         69
# bwv433_395  bwv433   G major                  4           395         68
# bwv371_456  bwv371   G major                  4           456        183
# bwv371_457  bwv371   G major                  4           457        182
# bwv371_458  bwv371   G major                  4           458        181
# bwv371_459  bwv371   G major                  4           459        180
# bwv436_192  bwv436   E major                  4           192        127
# bwv436_193  bwv436   E major                  4           193        126
# bwv436_194  bwv436   E major                  4           194        125
# bwv436_195  bwv436   E major                  4           195        124
# bwv437_112  bwv437   d minor                  4           112        399
# bwv437_113  bwv437   d minor                  4           113        398
# bwv437_114  bwv437   d minor                  4           114        397
# bwv437_115  bwv437   d minor                  4           115        396
# bwv437_440  bwv437   d minor                  4           440         71
# bwv437_441  bwv437   d minor                  4           441         70
# bwv437_442  bwv437   d minor                  4           442         69
# bwv437_443  bwv437   d minor                  4           443         68
#
#             forward_measure  back_measure  note_in_measure_position  \
# bwv346_76                 5            10                         9
# bwv346_77                 5            10                        10
# bwv346_78                 5            10                        11
# bwv346_79                 5            10                        12
# bwv346_124                8             7                         9
# bwv346_125                8             7                        10
# bwv346_126                8             7                        11
# bwv346_127                8             7                        12
# bwv341_44                 3             6                         9
# bwv341_45                 3             6                        10
# bwv341_46                 3             6                        11
# bwv341_47                 3             6                        12
# bwv341_92                 6             3                         9
# bwv341_93                 6             3                        10
# bwv341_94                 6             3                        11
# bwv341_95                 6             3                        12
# bwv427_28                 2            12                         9
# bwv427_29                 2            12                        10
# bwv427_30                 2            12                        11
# bwv427_31                 2            12                        12
# bwv427_60                 4            10                         9
# bwv427_61                 4            10                        10
# bwv427_62                 4            10                        11
# bwv427_63                 4            10                        12
# bwv427_92                 6             8                         9
# bwv427_93                 6             8                        10
# bwv427_94                 6             8                        11
# bwv427_95                 6             8                        12
# bwv427_156               10             4                         9
# bwv427_157               10             4                        10
# ...                     ...           ...                       ...
# bwv433_306               20             9                         3
# bwv433_307               20             9                         4
# bwv433_344               22             7                         9
# bwv433_345               22             7                        10
# bwv433_346               22             7                        11
# bwv433_347               22             7                        12
# bwv433_368               24             5                         1
# bwv433_369               24             5                         2
# bwv433_370               24             5                         3
# bwv433_371               24             5                         4
# bwv433_392               25             4                         9
# bwv433_393               25             4                        10
# bwv433_394               25             4                        11
# bwv433_395               25             4                        12
# bwv371_456               29            11                         9
# bwv371_457               29            11                        10
# bwv371_458               29            11                        11
# bwv371_459               29            11                        12
# bwv436_192               12             8                        13
# bwv436_193               12             8                        14
# bwv436_194               12             8                        15
# bwv436_195               12             8                        16
# bwv437_112                8            24                         1
# bwv437_113                8            24                         2
# bwv437_114                8            24                         3
# bwv437_115                8            24                         4
# bwv437_440               28             4                         9
# bwv437_441               28             4                        10
# bwv437_442               28             4                        11
# bwv437_443               28             4                        12
#
#             quarter_in_measure_position                   soprano  \
# bwv346_76                             3  <music21.note.Rest rest>
# bwv346_77                             3  <music21.note.Rest rest>
# bwv346_78                             3  <music21.note.Rest rest>
# bwv346_79                             3  <music21.note.Rest rest>
# bwv346_124                            3  <music21.note.Rest rest>
# bwv346_125                            3  <music21.note.Rest rest>
# bwv346_126                            3  <music21.note.Rest rest>
# bwv346_127                            3  <music21.note.Rest rest>
# bwv341_44                             3  <music21.note.Rest rest>
# bwv341_45                             3  <music21.note.Rest rest>
# bwv341_46                             3  <music21.note.Rest rest>
# bwv341_47                             3  <music21.note.Rest rest>
# bwv341_92                             3  <music21.note.Rest rest>
# bwv341_93                             3  <music21.note.Rest rest>
# bwv341_94                             3  <music21.note.Rest rest>
# bwv341_95                             3  <music21.note.Rest rest>
# bwv427_28                             3  <music21.note.Rest rest>
# bwv427_29                             3  <music21.note.Rest rest>
# bwv427_30                             3  <music21.note.Rest rest>
# bwv427_31                             3  <music21.note.Rest rest>
# bwv427_60                             3  <music21.note.Rest rest>
# bwv427_61                             3  <music21.note.Rest rest>
# bwv427_62                             3  <music21.note.Rest rest>
# bwv427_63                             3  <music21.note.Rest rest>
# bwv427_92                             3  <music21.note.Rest rest>
# bwv427_93                             3  <music21.note.Rest rest>
# bwv427_94                             3  <music21.note.Rest rest>
# bwv427_95                             3  <music21.note.Rest rest>
# bwv427_156                            3  <music21.note.Rest rest>
# bwv427_157                            3  <music21.note.Rest rest>
# ...                                 ...                       ...
# bwv433_306                            1  <music21.note.Rest rest>
# bwv433_307                            1  <music21.note.Rest rest>
# bwv433_344                            3  <music21.note.Rest rest>
# bwv433_345                            3  <music21.note.Rest rest>
# bwv433_346                            3  <music21.note.Rest rest>
# bwv433_347                            3  <music21.note.Rest rest>
# bwv433_368                            1  <music21.note.Rest rest>
# bwv433_369                            1  <music21.note.Rest rest>
# bwv433_370                            1  <music21.note.Rest rest>
# bwv433_371                            1  <music21.note.Rest rest>
# bwv433_392                            3  <music21.note.Rest rest>
# bwv433_393                            3  <music21.note.Rest rest>
# bwv433_394                            3  <music21.note.Rest rest>
# bwv433_395                            3  <music21.note.Rest rest>
# bwv371_456                            3  <music21.note.Rest rest>
# bwv371_457                            3  <music21.note.Rest rest>
# bwv371_458                            3  <music21.note.Rest rest>
# bwv371_459                            3  <music21.note.Rest rest>
# bwv436_192                            4  <music21.note.Rest rest>
# bwv436_193                            4  <music21.note.Rest rest>
# bwv436_194                            4  <music21.note.Rest rest>
# bwv436_195                            4  <music21.note.Rest rest>
# bwv437_112                            1  <music21.note.Rest rest>
# bwv437_113                            1  <music21.note.Rest rest>
# bwv437_114                            1  <music21.note.Rest rest>
# bwv437_115                            1  <music21.note.Rest rest>
# bwv437_440                            3  <music21.note.Rest rest>
# bwv437_441                            3  <music21.note.Rest rest>
# bwv437_442                            3  <music21.note.Rest rest>
# bwv437_443                            3  <music21.note.Rest rest>
#
#                                 alto                     tenor  \
# bwv346_76   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv346_77   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv346_78   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv346_79   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv346_124  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv346_125  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv346_126  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv346_127  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv341_44   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv341_45   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv341_46   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv341_47   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv341_92   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv341_93   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv341_94   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv341_95   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_28   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_29   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_30   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_31   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_60   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_61   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_62   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_63   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_92   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_93   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_94   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_95   <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_156  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv427_157  <music21.note.Rest rest>  <music21.note.Rest rest>
# ...                              ...                       ...
# bwv433_306  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv433_307  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv433_344  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv433_345  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv433_346  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv433_347  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv433_368  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv433_369  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv433_370  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv433_371  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv433_392  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv433_393  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv433_394  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv433_395  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv371_456  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv371_457  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv371_458  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv371_459  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv436_192  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv436_193  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv436_194  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv436_195  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv437_112  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv437_113  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv437_114  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv437_115  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv437_440  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv437_441  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv437_442  <music21.note.Rest rest>  <music21.note.Rest rest>
# bwv437_443  <music21.note.Rest rest>  <music21.note.Rest rest>
#
#                                 bass soprano_pitch_cat alto_pitch_cat  \
# bwv346_76   <music21.note.Rest rest>              Rest           Rest
# bwv346_77   <music21.note.Rest rest>              Rest           Rest
# bwv346_78   <music21.note.Rest rest>              Rest           Rest
# bwv346_79   <music21.note.Rest rest>              Rest           Rest
# bwv346_124  <music21.note.Rest rest>              Rest           Rest
# bwv346_125  <music21.note.Rest rest>              Rest           Rest
# bwv346_126  <music21.note.Rest rest>              Rest           Rest
# bwv346_127  <music21.note.Rest rest>              Rest           Rest
# bwv341_44   <music21.note.Rest rest>              Rest           Rest
# bwv341_45   <music21.note.Rest rest>              Rest           Rest
# bwv341_46   <music21.note.Rest rest>              Rest           Rest
# bwv341_47   <music21.note.Rest rest>              Rest           Rest
# bwv341_92   <music21.note.Rest rest>              Rest           Rest
# bwv341_93   <music21.note.Rest rest>              Rest           Rest
# bwv341_94   <music21.note.Rest rest>              Rest           Rest
# bwv341_95   <music21.note.Rest rest>              Rest           Rest
# bwv427_28   <music21.note.Rest rest>              Rest           Rest
# bwv427_29   <music21.note.Rest rest>              Rest           Rest
# bwv427_30   <music21.note.Rest rest>              Rest           Rest
# bwv427_31   <music21.note.Rest rest>              Rest           Rest
# bwv427_60   <music21.note.Rest rest>              Rest           Rest
# bwv427_61   <music21.note.Rest rest>              Rest           Rest
# bwv427_62   <music21.note.Rest rest>              Rest           Rest
# bwv427_63   <music21.note.Rest rest>              Rest           Rest
# bwv427_92   <music21.note.Rest rest>              Rest           Rest
# bwv427_93   <music21.note.Rest rest>              Rest           Rest
# bwv427_94   <music21.note.Rest rest>              Rest           Rest
# bwv427_95   <music21.note.Rest rest>              Rest           Rest
# bwv427_156  <music21.note.Rest rest>              Rest           Rest
# bwv427_157  <music21.note.Rest rest>              Rest           Rest
# ...                              ...               ...            ...
# bwv433_306  <music21.note.Rest rest>              Rest           Rest
# bwv433_307  <music21.note.Rest rest>              Rest           Rest
# bwv433_344  <music21.note.Rest rest>              Rest           Rest
# bwv433_345  <music21.note.Rest rest>              Rest           Rest
# bwv433_346  <music21.note.Rest rest>              Rest           Rest
# bwv433_347  <music21.note.Rest rest>              Rest           Rest
# bwv433_368  <music21.note.Rest rest>              Rest           Rest
# bwv433_369  <music21.note.Rest rest>              Rest           Rest
# bwv433_370  <music21.note.Rest rest>              Rest           Rest
# bwv433_371  <music21.note.Rest rest>              Rest           Rest
# bwv433_392  <music21.note.Rest rest>              Rest           Rest
# bwv433_393  <music21.note.Rest rest>              Rest           Rest
# bwv433_394  <music21.note.Rest rest>              Rest           Rest
# bwv433_395  <music21.note.Rest rest>              Rest           Rest
# bwv371_456  <music21.note.Rest rest>              Rest           Rest
# bwv371_457  <music21.note.Rest rest>              Rest           Rest
# bwv371_458  <music21.note.Rest rest>              Rest           Rest
# bwv371_459  <music21.note.Rest rest>              Rest           Rest
# bwv436_192  <music21.note.Rest rest>              Rest           Rest
# bwv436_193  <music21.note.Rest rest>              Rest           Rest
# bwv436_194  <music21.note.Rest rest>              Rest           Rest
# bwv436_195  <music21.note.Rest rest>              Rest           Rest
# bwv437_112  <music21.note.Rest rest>              Rest           Rest
# bwv437_113  <music21.note.Rest rest>              Rest           Rest
# bwv437_114  <music21.note.Rest rest>              Rest           Rest
# bwv437_115  <music21.note.Rest rest>              Rest           Rest
# bwv437_440  <music21.note.Rest rest>              Rest           Rest
# bwv437_441  <music21.note.Rest rest>              Rest           Rest
# bwv437_442  <music21.note.Rest rest>              Rest           Rest
# bwv437_443  <music21.note.Rest rest>              Rest           Rest
#
#            tenor_pitch_cat bass_pitch_cat
# bwv346_76             Rest           Rest
# bwv346_77             Rest           Rest
# bwv346_78             Rest           Rest
# bwv346_79             Rest           Rest
# bwv346_124            Rest           Rest
# bwv346_125            Rest           Rest
# bwv346_126            Rest           Rest
# bwv346_127            Rest           Rest
# bwv341_44             Rest           Rest
# bwv341_45             Rest           Rest
# bwv341_46             Rest           Rest
# bwv341_47             Rest           Rest
# bwv341_92             Rest           Rest
# bwv341_93             Rest           Rest
# bwv341_94             Rest           Rest
# bwv341_95             Rest           Rest
# bwv427_28             Rest           Rest
# bwv427_29             Rest           Rest
# bwv427_30             Rest           Rest
# bwv427_31             Rest           Rest
# bwv427_60             Rest           Rest
# bwv427_61             Rest           Rest
# bwv427_62             Rest           Rest
# bwv427_63             Rest           Rest
# bwv427_92             Rest           Rest
# bwv427_93             Rest           Rest
# bwv427_94             Rest           Rest
# bwv427_95             Rest           Rest
# bwv427_156            Rest           Rest
# bwv427_157            Rest           Rest
# ...                    ...            ...
# bwv433_306            Rest           Rest
# bwv433_307            Rest           Rest
# bwv433_344            Rest           Rest
# bwv433_345            Rest           Rest
# bwv433_346            Rest           Rest
# bwv433_347            Rest           Rest
# bwv433_368            Rest           Rest
# bwv433_369            Rest           Rest
# bwv433_370            Rest           Rest
# bwv433_371            Rest           Rest
# bwv433_392            Rest           Rest
# bwv433_393            Rest           Rest
# bwv433_394            Rest           Rest
# bwv433_395            Rest           Rest
# bwv371_456            Rest           Rest
# bwv371_457            Rest           Rest
# bwv371_458            Rest           Rest
# bwv371_459            Rest           Rest
# bwv436_192            Rest           Rest
# bwv436_193            Rest           Rest
# bwv436_194            Rest           Rest
# bwv436_195            Rest           Rest
# bwv437_112            Rest           Rest
# bwv437_113            Rest           Rest
# bwv437_114            Rest           Rest
# bwv437_115            Rest           Rest
# bwv437_440            Rest           Rest
# bwv437_441            Rest           Rest
# bwv437_442            Rest           Rest
# bwv437_443            Rest           Rest
#
# [528 rows x 17 columns]

# %%
bach_df = create_cont_pitch_vars(bach_df)

# %%
bach_df.head()
# Out:
#              BWV orig_key  beats_per_measure  forward_note  back_note  \
# bwv421_0  bwv421  a minor                  4             0        159
# bwv421_1  bwv421  a minor                  4             1        158
# bwv421_2  bwv421  a minor                  4             2        157
# bwv421_3  bwv421  a minor                  4             3        156
# bwv421_4  bwv421  a minor                  4             4        155
#
#           forward_measure  back_measure  note_in_measure_position  \
# bwv421_0                0            10                         1
# bwv421_1                0            10                         2
# bwv421_2                0            10                         3
# bwv421_3                0            10                         4
# bwv421_4                1             9                         1
#
#           quarter_in_measure_position                soprano       ...         \
# bwv421_0                            4  <music21.note.Note G>       ...
# bwv421_1                            4  <music21.note.Note G>       ...
# bwv421_2                            4  <music21.note.Note G>       ...
# bwv421_3                            4  <music21.note.Note G>       ...
# bwv421_4                            1  <music21.note.Note G>       ...
#
#                            tenor                    bass soprano_pitch_cat  \
# bwv421_0  <music21.note.Note B->   <music21.note.Note G>                G4
# bwv421_1  <music21.note.Note B->   <music21.note.Note G>                G4
# bwv421_2   <music21.note.Note C>   <music21.note.Note A>                G4
# bwv421_3   <music21.note.Note C>   <music21.note.Note A>                G4
# bwv421_4   <music21.note.Note D>  <music21.note.Note B->                G4
#
#          alto_pitch_cat tenor_pitch_cat bass_pitch_cat soprano_pitch_cont  \
# bwv421_0             D4             B-3             G2                  1
# bwv421_1             D4             B-3             G2                  1
# bwv421_2             D4              C4             A2                  1
# bwv421_3             D4              C4             A2                  1
# bwv421_4             D4              D4            B-2                  1
#
#           alto_pitch_cont  tenor_pitch_cont  bass_pitch_cont
# bwv421_0               -4                -8              -23
# bwv421_1               -4                -8              -23
# bwv421_2               -4                -6              -21
# bwv421_3               -4                -6              -21
# bwv421_4               -4                -4              -20
#
# [5 rows x 21 columns]

# %% [markdown]
# ![](../presentation/yay_gifs/dwight.gif)

# %%
bach_df.describe()
# Out:
#        beats_per_measure  forward_note    back_note  forward_measure  \
# count       46676.000000   46676.00000  46676.00000     46676.000000
# mean            3.860828     165.51474    165.51474        11.208501
# std             0.346130     190.88104    190.88104        12.216570
# min             3.000000       0.00000      0.00000         0.000000
# 25%             4.000000      63.00000     63.00000         4.000000
# 50%             4.000000     127.00000    127.00000         9.000000
# 75%             4.000000     204.00000    204.00000        14.000000
# max             4.000000    1699.00000   1699.00000       106.000000
#
#        back_measure  note_in_measure_position  quarter_in_measure_position  \
# count  46676.000000              46676.000000                  46676.00000
# mean      10.550947                  8.098766                      2.42960
# std       12.216967                  4.534788                      1.10032
# min        0.000000                  1.000000                      1.00000
# 25%        4.000000                  4.000000                      1.00000
# 50%        8.000000                  8.000000                      2.00000
# 75%       13.000000                 12.000000                      3.00000
# max      106.000000                 40.000000                     10.00000
#
#        soprano_pitch_cont  alto_pitch_cont  tenor_pitch_cont  bass_pitch_cont
# count        46676.000000     46676.000000      46676.000000     46676.000000
# mean         11316.981554     11825.955737      12034.797498     12368.615134
# std         105755.325612    108104.594504     109068.178743    110591.669100
# min             -8.000000       -13.000000        -18.000000       -32.000000
# 25%              1.000000        -4.000000         -9.000000       -18.000000
# 50%              5.000000         0.000000         -6.000000       -15.000000
# 75%              8.000000         3.000000         -3.000000       -11.000000
# max        1000000.000000   1000000.000000    1000000.000000   1000000.000000

# %%
f = open('complete_bach.p','wb')
cPickle.dump(bach_df, f)
f.close()

# %%
clean_bach = bach_df.drop(['soprano','alto','tenor','bass'], axis=1)

# %%
f = open('clean_bach.p','wb')
cPickle.dump(clean_bach, f)
f.close()

# %% [markdown]
# ## Data Visualizations
# To be filled in later.
#
# The purpose of this section is to show the underlying trends in the music. The hope is that the model picks up on these trends that reflect what music majors learn are the basics of composition.
#
# I don't have a way to exactly evaluate quantitatively how well the models perform. I only have my ears. But I can show you the charts for the compositions I am making!

# %%
# create a histogram of the frequency of notes by part
# x-axis is all pitches, lined up. you can set it using the continuous
# variables but label them with categorical. y is the # of times they
# show up. use different colors for each voice part

# %%
# can i show a histogram that shows frequency of pitches by CHORD?
# ie I chord vs V chord vs IV chord?

# %%
# a visualization that shows frequency of pitch BY POSITION IN THE MEASURE
# ie. G occurs most often when quarter = 1, and F# shows up most when 
# quarter = 4

# %%
# histogram of the keys/harmonies that show up in each piece. 
# Need to add this to the dataframe later.

# %% [markdown]
# -----------
# ## Please go on to the third page of this technical report, available back in the Github folder.
